# %% [markdown]
# <p style="text-align:center">
#     <a href="https://github.com/ITHealer?tab=repositories" target="_blank">
#     <img src="avatar_healer.jpg" width="200" alt="Link github"  />
#     </a>
# </p>

# %% [markdown]
# <h1>Table of contents</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a>Collection data</a></li>
#         <li><a>Pre-processing</a></li>
#         <li><a>Word Embedding</a></li>
#         <li><a>Modeling</a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# <details><summary><font color=green>Details</font></summary>
#
#
# </details>

# %% [markdown]
# <font color=red>Fill or drop tag</font>

# %%
# import library 
import numpy as np
import pandas as pd

# %%
df_file1 = pd.read_excel('dulieu.xlsx')
df_file1.head()
# Out:
#                Họ tên  GT  Mã ngành Khối   M1    M2    M3  Mã tỉnh
# 0        LA LAN THỊ Ả  Nữ   7380101  C00  5.0  3.75  3.75       39
# 1       NGÔ THỊ MỸ ÁI  Nữ   7340101  D01  5.2  6.00  4.20       35
# 2  NGUYỄN THỊ THÚY ÁI  Nữ   7340301  D01  5.0  6.50  1.80       38
# 3   NGUYỄN TÔ VĨNH ÁI  Nữ   7340101  D01  5.8  6.25  4.60       37
# 4     PHẠM THỊ KIM ÁI  Nữ   7340101  D01  6.8  6.75  5.40       39

# %%
df_file2 = pd.read_excel('tinh.xlsx')
df_file2.head()
# Out:
#    Mã tỉnh         Tên tỉnh
# 0        1           Hà Nội
# 1        2  Tp. Hồ Chí Minh
# 2        2    Tp. Hồ Hồ Chí
# 3        3        Hải Phòng
# 4        4          Đà Nẵng

# %%
df = pd.merge(df_file1, df_file2,how='outer',left_on=['Mã tỉnh'],right_on=['Mã tỉnh'])

# %%
df
# Out:
#                   Họ tên   GT   Mã ngành Khối    M1    M2    M3  Mã tỉnh  \
# 0           LA LAN THỊ Ả   Nữ  7380101.0  C00  5.00  3.75  3.75       39
# 1        PHẠM THỊ KIM ÁI   Nữ  7340101.0  D01  6.80  6.75  5.40       39
# 2               KPĂ Y AN   Nữ  7310205.0  C00  4.75  3.75  6.25       39
# 3           LÊ MÔ HÒA AN   Nữ  7340101.0  A00  4.60  4.75  4.50       39
# 4     TRƯƠNG THỊ XUÂN AN  Nam  7340101.0  D01  5.80  5.25  4.60       39
# ...                  ...  ...        ...  ...   ...   ...   ...      ...
# 2745                 NaN  NaN        NaN  NaN   NaN   NaN   NaN       58
# 2746                 NaN  NaN        NaN  NaN   NaN   NaN   NaN       59
# 2747                 NaN  NaN        NaN  NaN   NaN   NaN   NaN       60
# 2748                 NaN  NaN        NaN  NaN   NaN   NaN   NaN       61
# 2749                 NaN  NaN        NaN  NaN   NaN   NaN   NaN       64
#
#        Tên tỉnh  Tổng điểm
# 0       Phú Yên      12.50
# 1       Phú Yên      18.95
# 2       Phú Yên      14.75
# 3       Phú Yên      13.85
# 4       Phú Yên      15.65
# ...         ...        ...
# 2745   Trà Vinh       0.00
# 2746  Sóc Trăng       0.00
# 2747   Bạc Liêu       0.00
# 2748     Cà Mau       0.00
# 2749  Hậu Giang       0.00
#
# [2750 rows x 10 columns]

# %%
df['Tổng điểm'] = (df[['M1','M2','M3']].sum(1))

# %%
df.head()
# Out:
#                Họ tên   GT   Mã ngành Khối    M1    M2    M3  Mã tỉnh  \
# 0        LA LAN THỊ Ả   Nữ  7380101.0  C00  5.00  3.75  3.75       39
# 1     PHẠM THỊ KIM ÁI   Nữ  7340101.0  D01  6.80  6.75  5.40       39
# 2            KPĂ Y AN   Nữ  7310205.0  C00  4.75  3.75  6.25       39
# 3        LÊ MÔ HÒA AN   Nữ  7340101.0  A00  4.60  4.75  4.50       39
# 4  TRƯƠNG THỊ XUÂN AN  Nam  7340101.0  D01  5.80  5.25  4.60       39
#
#   Tên tỉnh  Tổng điểm
# 0  Phú Yên      12.50
# 1  Phú Yên      18.95
# 2  Phú Yên      14.75
# 3  Phú Yên      13.85
# 4  Phú Yên      15.65

# %%
df['Họ tên'].groupby(df['GT'])

# %%
"Hoai"[3]
# Out:
# 'i'

# %%
print(divmod(8, 3))
# Out:
# (2, 2)

# %%
import math
math.factorial(4)
# Out:
# 24

# %%
lst = [1, 2, 3, 4]
math.fsum(lst)
# Out:
# 10.0

# %%
math.hypot(2, 2)
# Out:
# 2.8284271247461903

# %%
any(df[c].hasnans for c in df)
# Out:
# True

# %%
nan_rows = df[df.isnull().any(1)]
nan_rows
# Out:
#      Họ tên   GT  Mã ngành Khối  M1  M2  M3  Mã tỉnh         Tên tỉnh  \
# 2714    NaN  NaN       NaN  NaN NaN NaN NaN        2  Tp. Hồ Chí Minh
# 2715    NaN  NaN       NaN  NaN NaN NaN NaN        2    Tp. Hồ Hồ Chí
# 2716    NaN  NaN       NaN  NaN NaN NaN NaN        3        Hải Phòng
# 2717    NaN  NaN       NaN  NaN NaN NaN NaN        5         Hà Giang
# 2718    NaN  NaN       NaN  NaN NaN NaN NaN        6         Cao Bằng
# 2719    NaN  NaN       NaN  NaN NaN NaN NaN        7         Lai Châu
# 2720    NaN  NaN       NaN  NaN NaN NaN NaN        8          Lào Cai
# 2721    NaN  NaN       NaN  NaN NaN NaN NaN        9      Tuyên Quang
# 2722    NaN  NaN       NaN  NaN NaN NaN NaN       11          Bắc Kạn
# 2723    NaN  NaN       NaN  NaN NaN NaN NaN       12      Thái Nguyên
# 2724    NaN  NaN       NaN  NaN NaN NaN NaN       13          Yên Bái
# 2725    NaN  NaN       NaN  NaN NaN NaN NaN       14           Sơn La
# 2726    NaN  NaN       NaN  NaN NaN NaN NaN       15          Phú Thọ
# 2727    NaN  NaN       NaN  NaN NaN NaN NaN       16        Vĩnh Phúc
# 2728    NaN  NaN       NaN  NaN NaN NaN NaN       17       Quảng Ninh
# 2729    NaN  NaN       NaN  NaN NaN NaN NaN       18        Bắc Giang
# 2730    NaN  NaN       NaN  NaN NaN NaN NaN       21        Hải Dương
# 2731    NaN  NaN       NaN  NaN NaN NaN NaN       22         Hưng Yên
# 2732    NaN  NaN       NaN  NaN NaN NaN NaN       23         Hoà Bình
# 2733    NaN  NaN       NaN  NaN NaN NaN NaN       24           Hà Nam
# 2734    NaN  NaN       NaN  NaN NaN NaN NaN       27        Ninh Bình
# 2735    NaN  NaN       NaN  NaN NaN NaN NaN       33  Thừa Thiên -Huế
# 2736    NaN  NaN       NaN  NaN NaN NaN NaN       44       Bình Dương
# 2737    NaN  NaN       NaN  NaN NaN NaN NaN       46         Tây Ninh
# 2738    NaN  NaN       NaN  NaN NaN NaN NaN       51         An Giang
# 2739    NaN  NaN       NaN  NaN NaN NaN NaN       52  Bà Rịa-Vũng Tàu
# 2740    NaN  NaN       NaN  NaN NaN NaN NaN       53       Tiền Giang
# 2741    NaN  NaN       NaN  NaN NaN NaN NaN       54       Kiên Giang
# 2742    NaN  NaN       NaN  NaN NaN NaN NaN       55          Cần Thơ
# 2743    NaN  NaN       NaN  NaN NaN NaN NaN       56          Bến Tre
# 2744    NaN  NaN       NaN  NaN NaN NaN NaN       57        Vĩnh Long
# 2745    NaN  NaN       NaN  NaN NaN NaN NaN       58         Trà Vinh
# 2746    NaN  NaN       NaN  NaN NaN NaN NaN       59        Sóc Trăng
# 2747    NaN  NaN       NaN  NaN NaN NaN NaN       60         Bạc Liêu
# 2748    NaN  NaN       NaN  NaN NaN NaN NaN       61           Cà Mau
# 2749    NaN  NaN       NaN  NaN NaN NaN NaN       64        Hậu Giang
#
#       Tổng điểm
# 2714        0.0
# 2715        0.0
# 2716        0.0
# 2717        0.0
# 2718        0.0
# 2719        0.0
# 2720        0.0
# 2721        0.0
# 2722        0.0
# 2723        0.0
# 2724        0.0
# 2725        0.0
# 2726        0.0
# 2727        0.0
# 2728        0.0
# 2729        0.0
# 2730        0.0
# 2731        0.0
# 2732        0.0
# 2733        0.0
# 2734        0.0
# 2735        0.0
# 2736        0.0
# 2737        0.0
# 2738        0.0
# 2739        0.0
# 2740        0.0
# 2741        0.0
# 2742        0.0
# 2743        0.0
# 2744        0.0
# 2745        0.0
# 2746        0.0
# 2747        0.0
# 2748        0.0
# 2749        0.0

# %%
df.loc[:, df.isnull().any()].columns
# Out:
# Index(['Họ tên', 'GT', 'Mã ngành', 'Khối', 'M1', 'M2', 'M3'], dtype='object')

# %%
df.isnull().any()
# Out:
# Họ tên        True
# GT            True
# Mã ngành      True
# Khối          True
# M1            True
# M2            True
# M3            True
# Mã tỉnh      False
# Tên tỉnh     False
# Tổng điểm    False
# dtype: bool

# %%
df.loc[:,list(df.loc[:,df.isnull().any()].columns)].isnull().sum()/(len(df))*100
# Out:
# Họ tên      1.309091
# GT          1.309091
# Mã ngành    1.309091
# Khối        1.309091
# M1          1.309091
# M2          1.309091
# M3          1.309091
# dtype: float64
